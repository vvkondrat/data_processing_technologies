# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.DataFrame(pd.read_csv('data/recipes_sample.csv', parse_dates=['submitted']))


recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %%
reviews = pd.DataFrame(pd.read_csv('data/reviews_sample.csv'))
reviews.sort_values(by='recipe_id')
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 120108      532499       68674         48  2004-05-03       2
# 47487       532498       32421         48  2002-03-15       0
# 102582      462146     1060485         55  2009-04-07       5
# 55338       462147      851190         55  2010-05-23       5
# 2526        462145      165567         55  2006-03-31       5
# ...            ...         ...        ...         ...     ...
# 64742       744576     1925885     536729  2018-08-16       5
# 31002       631001  2001285346     536747  2018-09-06       0
# 10827       631002  2002007477     536747  2018-09-06       0
# 29803       631003     1460111     536747  2018-09-26       0
# 103137      631000  2001996022     536747  2018-09-06       0
#
#                                                    review
# 120108  I picked this recipe over the other BCP recipe...
# 47487   The flavor was great. But I think there was no...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
rows_recipes, columns_recipes, columns_type_recipes = recipes.shape[0], recipes.shape[1], recipes.dtypes
print(rows_recipes, columns_recipes)
print(columns_type_recipes)

print('---------------')

rows_reviews, columns_reviews, columns_type_reviews = reviews.shape[0], reviews.shape[1], reviews.dtypes
print(rows_reviews, columns_reviews)
print(columns_type_reviews)
# Out:
# 30000 8
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object
# ---------------
# 126696 6
# Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
count_nan_recipes = recipes.isnull().sum()
print(count_nan_recipes)

print('-----------------')

count_nan_reviews = reviews.isnull().sum()
print(count_nan_reviews)

c_rows_nan_recipes = len(recipes[recipes.count(axis=1) < recipes.shape[1]]) / recipes.shape[0] * 100
c_rows_nan_reviews = len(reviews[reviews.count(axis=1) < reviews.shape[1]]) / reviews.shape[0] * 100

print('-----------------')

print(c_rows_nan_recipes, '%')
print(c_rows_nan_reviews, '%')
# Out:
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
# -----------------
# Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64
# -----------------
# 56.846666666666664 %
# 0.013417945317926377 %

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
mean_minutes_recipes = recipes['minutes'].mean()
mean_n_steps_recipes = recipes['n_steps'].mean()
mean_n_ingredients_recipes = recipes['n_ingredients'].mean()
print(mean_minutes_recipes, mean_n_steps_recipes, mean_n_ingredients_recipes)

mean_rating_reviews = reviews['rating'].mean()
print(mean_rating_reviews)
# Out:
# 123.35813333333333 9.805582137161085 9.008285984848484
# 4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
result = pd.Series(recipes['name'].sample(n=10))
print(result)
# Out:
# 29865                        zesty style potato wedges
# 13760    ho yau ngau  stir fried steak w  oyster sauce
# 19014                             oh so easy sweet tea
# 6681               chocolate no bake cookies with nuts
# 20815                              pineapple ice cream
# 10894                                 festive red slaw
# 15345          kidd kraddick s famous brown bag turkey
# 26700                                sweet onion jelly
# 21854                        quick  n  crunchy granola
# 21644                      pumpkin   sweet basil pasta
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.reindex(np.arange(1, len(reviews)))
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 1           624300      431813     142201  2007-09-16       5
# 2           187037      400708     252013  2008-01-10       4
# 3           706134  2001852463     404716  2017-12-11       5
# 4           312179       95810     129396  2008-03-14       5
# 5           910362       35106      31322  2003-01-03       4
# ...            ...         ...        ...         ...     ...
# 126691     1013457     1270706     335534  2009-05-17       4
# 126692      158736     2282344       8701  2012-06-03       0
# 126693     1059834      689540     222001  2008-04-08       5
# 126694      453285  2000242659     354979  2015-06-02       5
# 126695      691207      463435     415599  2010-09-30       5
#
#                                                    review
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes.loc[(recipes["minutes"] <= 20) & (recipes["n_ingredients"] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
filtred_dt = recipes[(recipes['submitted'] <= pd.to_datetime('2010-12-31'))]
filtred_dt
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     Zuni caf zucchini pickles  316950     2895
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['decsription_length'] = recipes['description'].str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.capitalize()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes['name_word_count'] = recipes['name'].str.split().str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
count = recipes['contributor_id'].value_counts()
max_from_count = max(count)

print(count)
print(max_from_count)
# Out:
# contributor_id
# 89831      421
# 37449      346
# 37779      345
# 1533       186
# 169430     183
#           ...
# 1061628      1
# 1076183      1
# 429061       1
# 64032        1
# 186118       1
# Name: count, Length: 8404, dtype: int64
# 421

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
rating_mean = reviews.groupby('recipe_id')['rating'].mean()
uniques_recipes_id = np.unique(reviews['recipe_id'])
recipes_with_no_reviews = recipes['id']

# количество рецептов, для которых отсутсвуют отзывы
print(len(recipes_with_no_reviews) - len(uniques_recipes_id))

# средний рейтинг к каждому из рецептов
print(rating_mean)
# Out:
# 1900
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
df = recipes['submitted'].dt.year.value_counts()
df
# Out:
# submitted
# 2007    4429
# 2008    4029
# 2006    3473
# 2005    3130
# 2009    2963
# 2002    2644
# 2003    2334
# 2004    2153
# 2010    1538
# 2011     922
# 2012     659
# 2001     589
# 2013     490
# 1999     275
# 2014     139
# 2000     104
# 2015      42
# 2017      39
# 2016      24
# 2018      24
# Name: count, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
new_df = pd.merge(recipes.iloc[:, :2], reviews.iloc[:,[1,4]], how='inner', left_on='id', right_on=reviews['recipe_id'])

# количество уникальный рецептов в новом DataFrame, на которые есть отзывы
ids = np.unique(new_df['id'])
print(len(ids))

# количество всех рецептов, то же самое что и длина всего DataFrame "recipes"
ids_full = recipes['id']
print(len(ids_full))

# => количество рецептов, на которые отсуствуцют отзывы = 1900

# находим эти рецепты и получаем новый DataFrame
recipes_with_no_reviews=recipes.loc[~recipes['id'].isin(new_df['id'])]

# проверяем наличие этого рецепта в новом DataFrame new_df
recipes_with_no_reviews.iloc[1,1] in (new_df['id'])
new_df.sort_values('name')
recipes_with_no_reviews
# Out:
# 28100
# 30000
#                                           name      id  minutes  \
# 26               Pasta  with shrimp   eggplant  223349       50
# 29             Secret ingredient  bbq meatloaf  342620       75
# 35           Windy s  sweet and sour meatballs  276594       50
# 49     Goulashy  beef stew for the slow cooker  216068      430
# 59                Old bay  grilled steak fries  306590       20
# ...                                        ...     ...      ...
# 29871                       Zingy potato salad   66966       45
# 29903       Zucchini  mock green papaya  salad  249846       15
# 29905            Zucchini and corn with cheese  256177       15
# 29951                       Zucchini nut salad  178243       30
# 29979     Zucchini with bell pepper and tomato  363362       13
#
#        contributor_id  submitted  n_steps  \
# 26             452592 2007-04-18      7.0
# 29              50969 2008-12-09      9.0
# 35             341338 2008-01-05      6.0
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
df = pd.DataFrame(pd.merge(reviews.iloc[:,[2]], recipes.iloc[:, [0]], how='inner', left_on='recipe_id', right_on=recipes['id']).groupby('recipe_id').value_counts())

#df = df.rename(columns={'X1': 'A', 'X2': 'B', 'X3': 'C', 'X4': 'D', 'X5': 'E'
df_no_reviews = pd.DataFrame(recipes_with_no_reviews.iloc[:,[1,0]])
df_no_reviews = df_no_reviews.rename(columns={'id': 'recipe_id'})
df2 = pd.concat([df, df_no_reviews], ignore_index=True)
df.set_index('index')

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23076\3702376258.py in ?()
#       3 #df = df.rename(columns={'X1': 'A', 'X2': 'B', 'X3': 'C', 'X4': 'D', 'X5': 'E'
#       4 df_no_reviews = pd.DataFrame(recipes_with_no_reviews.iloc[:,[1,0]])
#       5 df_no_reviews = df_no_reviews.rename(columns={'id': 'recipe_id'})
#       6 df2 = pd.concat([df, df_no_reviews], ignore_index=True)
# ----> 7 df.set_index('index')
#       8
#       9 df
#
# d:\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# ...

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
df1 = pd.merge(recipes.iloc[:,[1,4]], reviews.iloc[:,[4]], how='inner', left_on='id', right_on=reviews['recipe_id'])
df1 = pd.DataFrame(df1.groupby(df1.submitted.dt.year)['rating'].mean())

result = df1[df1['rating'] == df1['rating'].min()]
result
# Out:
#            rating
# submitted
# 2017         2.75

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes.sort_values(by='name_word_count')
recipes.to_csv('new_recipes.csv')
# Out:
#                                                     name      id  minutes  \
# 15528                                             Kuchen   77329       63
# 29455                                            Wimpies   75064       55
# 23287                                         Salscamole  295204        2
# 19437                                       Orangecicles  119528       65
# 1587                                         Babaganoush  375602       40
# ...                                                  ...     ...      ...
# 5734   Chicken curry or  cat s vomit on a bed of magg...  294898       30
# 26222  Subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  Top secret recipes version of  i h o p  griddl...  113346       20
# 28083  Tsr version of t g i  friday s black bean soup...  102274       75
# 26223  Subru uncle s whole green moong dal i ll be ma...   77188       95
#
#        contributor_id  submitted  n_steps  \
# ...

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter('recipes_new.xlsx') as writer:
    new_df.to_excel(writer, sheet_name='Рецепты c оценками')
    df.to_excel(writer, sheet_name='Количество отзывов по рецептам')

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
